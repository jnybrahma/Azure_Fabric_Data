# %%
df = spark.read.table("mtomactual")
display(df)
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d35b658d-939d-42a4-83b6-c64a2e75630b)

# %%
df2 = spark.read.format("delta").load("Tables/dbo/mtomactual")

display(df2)
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 2c7a3ae0-467e-4412-a218-68624c15a848)

# %%
# %%sql
#
# SELECT *  FROM mtomactual
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 6, Finished, Available, Finished, False)
# <Spark SQL result set with 6 rows and 3 fields>

# %%
df.collect()
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 7, Finished, Available, Finished, False)
# [Row(Country='England', Location='London', Actual='5000'),
#  Row(Country='England', Location='Birmingham', Actual='7000'),
#  Row(Country='England', Location='Manchester', Actual='11000'),
#  Row(Country='France', Location='Paris', Actual='4000'),
#  Row(Country='Italy', Location='Milan', Actual='3000'),
#  Row(Country='Italy', Location='Rome', Actual='13000')]

# %%
df.schema
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 8, Finished, Available, Finished, False)
# StructType([StructField('Country', StringType(), True), StructField('Location', StringType(), True), StructField('Actual', StringType(), True)])

# %%
df.summary
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 9, Finished, Available, Finished, False)
# <bound method DataFrame.summary of DataFrame[Country: string, Location: string, Actual: string]>

# %%
df.show()
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 10, Finished, Available, Finished, False)
# +-------+----------+------+
# |Country|  Location|Actual|
# +-------+----------+------+
# |England|    London|  5000|
# |England|Birmingham|  7000|
# |England|Manchester| 11000|
# | France|     Paris|  4000|
# |  Italy|     Milan|  3000|
# |  Italy|      Rome| 13000|
# +-------+----------+------+

# %%
# dfreduced = df.select("Country", "Actual")  # not case sensitive

# dfreduced = df.select(df.Country, df.Actual) # is case sensitive

dfreduced = df.select(df.Country, df.Actual.alias("ActualSales"))


display(dfreduced)
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 16, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 29f69ad0-236c-4b28-ad8d-127b2d9e5aec)

# %%
# %%sql
# SELECT Country , Actual AS ActualSales
# FROM mtomactual
# Out:
# StatementMeta(, 78126519-b4fa-42d8-b769-b490871aaadf, 17, Finished, Available, Finished, False)
# <Spark SQL result set with 6 rows and 2 fields>
