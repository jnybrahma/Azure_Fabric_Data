# %%
df = spark.read.table("mtomactual")
display(df)
# Out:
# StatementMeta(, 04ec8482-c11c-4cf9-95c1-c041a2ffdfa4, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 48d41386-9eb8-46bc-8049-1a4e9d9e2b36)

# %%
df2 = spark.read.format("delta").load("Tables/dbo/mtomactual")

display(df2)
# Out:
# StatementMeta(, 04ec8482-c11c-4cf9-95c1-c041a2ffdfa4, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 026b4cff-e3e1-4962-9200-4e3b100485ec)

# %%
# %%sql
#
# SELECT *  FROM mtomactual
# Out:
# StatementMeta(, 04ec8482-c11c-4cf9-95c1-c041a2ffdfa4, 7, Finished, Available, Finished, False)
# <Spark SQL result set with 6 rows and 3 fields>

# %%
df.collect()
# Out:
# StatementMeta(, 04ec8482-c11c-4cf9-95c1-c041a2ffdfa4, 8, Finished, Available, Finished, False)
# [Row(Country='England', Location='London', Actual='5000'),
#  Row(Country='England', Location='Birmingham', Actual='7000'),
#  Row(Country='England', Location='Manchester', Actual='11000'),
#  Row(Country='France', Location='Paris', Actual='4000'),
#  Row(Country='Italy', Location='Milan', Actual='3000'),
#  Row(Country='Italy', Location='Rome', Actual='13000')]

# %%
df.schema
# Out:
# StatementMeta(, 04ec8482-c11c-4cf9-95c1-c041a2ffdfa4, 9, Finished, Available, Finished, False)
# StructType([StructField('Country', StringType(), True), StructField('Location', StringType(), True), StructField('Actual', StringType(), True)])

# %%
df.summary
# Out:
# StatementMeta(, 04ec8482-c11c-4cf9-95c1-c041a2ffdfa4, 10, Finished, Available, Finished, False)
# <bound method DataFrame.summary of DataFrame[Country: string, Location: string, Actual: string]>

# %%
df.show()
# Out:
# StatementMeta(, 04ec8482-c11c-4cf9-95c1-c041a2ffdfa4, 12, Finished, Available, Finished, False)
# +-------+----------+------+
# |Country|  Location|Actual|
# +-------+----------+------+
# |England|    London|  5000|
# |England|Birmingham|  7000|
# |England|Manchester| 11000|
# | France|     Paris|  4000|
# |  Italy|     Milan|  3000|
# |  Italy|      Rome| 13000|
# +-------+----------+------+
