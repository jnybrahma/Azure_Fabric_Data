# %%
df = spark.read.table("mtomactual")
display(df)
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, eb660b6a-d4f8-4a9c-8edf-7a8268ba5ec6)

# %%
df2 = spark.read.format("delta").load("Tables/dbo/mtomactual")

display(df2)
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 634f95d7-09e1-49ec-8ce2-a59876c3531e)

# %%
# %%sql
#
# SELECT *  FROM mtomactual
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 5, Finished, Available, Finished, False)
# <Spark SQL result set with 6 rows and 3 fields>

# %%
df.collect()
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 6, Finished, Available, Finished, False)
# [Row(Country='England', Location='London', Actual='5000'),
#  Row(Country='England', Location='Birmingham', Actual='7000'),
#  Row(Country='England', Location='Manchester', Actual='11000'),
#  Row(Country='France', Location='Paris', Actual='4000'),
#  Row(Country='Italy', Location='Milan', Actual='3000'),
#  Row(Country='Italy', Location='Rome', Actual='13000')]

# %%
df.schema
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 7, Finished, Available, Finished, False)
# StructType([StructField('Country', StringType(), True), StructField('Location', StringType(), True), StructField('Actual', StringType(), True)])

# %%
df.summary
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 8, Finished, Available, Finished, False)
# <bound method DataFrame.summary of DataFrame[Country: string, Location: string, Actual: string]>

# %%
df.show()
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 9, Finished, Available, Finished, False)
# +-------+----------+------+
# |Country|  Location|Actual|
# +-------+----------+------+
# |England|    London|  5000|
# |England|Birmingham|  7000|
# |England|Manchester| 11000|
# | France|     Paris|  4000|
# |  Italy|     Milan|  3000|
# |  Italy|      Rome| 13000|
# +-------+----------+------+

# %%
# dfreduced = df.select("Country", "Actual")  # not case sensitive

# dfreduced = df.select(df.Country, df.Actual) # is case sensitive

dfreduced = df.select(df.Country, df.Actual.alias("ActualSales"))


display(dfreduced)
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, b638c615-c75f-4d0a-8928-821a7d75fc3c)

# %%
# %%sql
# SELECT Country , Actual AS ActualSales
# FROM mtomactual
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 11, Finished, Available, Finished, False)
# <Spark SQL result set with 6 rows and 2 fields>

# %%
dfreduced = df.select(df.Country, df.Actual.alias("ActualSales"))


display(dfreduced.where("Country <= 'England'"))
#display(dfreduced.where("Country >= 'England'"))
display(dfreduced.where("Country > 'England'"))
display(dfreduced.limit(3))
display(dfreduced.tail(2))
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 22, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 5b0bb163-482b-4cd3-ab7f-19aae236622f)
# SynapseWidget(Synapse.DataFrame, 7dbf7ff4-0efe-451f-adc5-c7a1a2a42438)
# SynapseWidget(Synapse.DataFrame, c96f2877-4eea-4ae2-b54e-78fe023b1f8e)
# SynapseWidget(Synapse.DataFrame, 8160e680-b8bb-4543-81f3-f3802d72130b)

# %%
display(dfreduced.filter(dfreduced.Country == "England"))
display(dfreduced.filter("ActualSales > 10000"))
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 19, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 230ce2b2-680f-4a78-b296-ef43eec8b0bc)
# SynapseWidget(Synapse.DataFrame, a357dfe2-1532-46bd-a8e8-b097400d2bcf)

# %%
# %%sql
# SELECT Country , Actual AS ActualSales
# FROM mtomactual
# WHERE Country = "England"
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 17, Finished, Available, Finished, False)
# <Spark SQL result set with 3 rows and 2 fields>

# %%
# %%sql
# SELECT Country , Actual AS ActualSales
# FROM mtomactual
# WHERE Country <> "England"
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 18, Finished, Available, Finished, False)
# <Spark SQL result set with 3 rows and 2 fields>

# %%
display(df.withColumn("ActualDoubled", df.Actual* 2)\
       .withColumn("SecondLetter", df.Country.substr(2,1))
)
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 26, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a330b4c3-31f4-46c4-8d47-2b6914146bf4)

# %%
# %%sql
# SELECT *, Actual * 2 AS ActualDoubled, substr(Country,2,1) AS SecondLetter
# FROM mtomactual
# Out:
# StatementMeta(, 99a9aeb9-88cf-4d6e-8554-e37da9d788e6, 27, Finished, Available, Finished, False)
# <Spark SQL result set with 6 rows and 5 fields>
