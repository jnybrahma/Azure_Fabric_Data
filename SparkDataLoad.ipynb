# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df = spark.read.format("csv").option("header","true").load("Files/MtoMActual.csv")
# df now is a Spark DataFrame containing CSV data from "Files/MtoMActual.csv".
display(df)
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, bf3f9c79-4481-4faf-b9de-8e66afa443a7)

# %%
df2 = spark.read.csv("Files/MtoMActual.csv",header=True)

display(df2)
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 11, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c88a5042-3ff4-4799-a0c9-c4ffa42d7a70)

# %%
df3 = spark.read.load("Files/MtoMActual.csv", format='csv', header=True)
# df now is a Spark DataFrame containing CSV data from "Files/MtoMActual.csv".
display(df3)
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f9d1cb65-ca2f-49d1-9290-a161221254d9)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/MtoMActual.csv"
df4 = pd.read_csv("/lakehouse/default/Files/MtoMActual.csv")
display(df4)
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 12, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 4688e757-fbab-4031-bfaf-911ad73d2cf5)
