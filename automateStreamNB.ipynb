# %%
df = spark.read.format("csv").option("header", "true").load("Files/Shopping.csv")

display(df)
# Out:
# StatementMeta(, b1757f67-87f2-466f-8d38-cacfbc2b8c5b, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ea75c83f-7b48-4b3e-bc4e-201f47ffd735)

# %%
df.schema
# Out:
# StatementMeta(, b1757f67-87f2-466f-8d38-cacfbc2b8c5b, 5, Finished, Available, Finished, False)
# StructType([StructField('Date', StringType(), True), StructField('Subtype', StringType(), True), StructField('PurchaseMethod', StringType(), True), StructField('Out', StringType(), True)])

# %%
from pyspark.sql.types import StructField, StructType, StringType

schema = StructType([StructField('Date', StringType(), True),
StructField('Subtype', StringType(), True), 
StructField('PurchaseMethod', StringType(), True), 
StructField('Out', StringType(), True)])

dfs = spark.readStream.option("header", "true").schema(schema).format("csv").load("Files/Shop*.csv")
deltatablepath = "Tables/Shop_table"
query = dfs.writeStream.format("delta").outputMode("append").option("checkpointLocation", deltatablepath + '/_checkpoint') \
            .option("path", deltatablepath).start()

query.awaitTermination()
# Out:
# StatementMeta(, b1757f67-87f2-466f-8d38-cacfbc2b8c5b, 6, Submitted, Running, Running, True)
