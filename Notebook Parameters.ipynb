# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
ParameterCountry = "England"
# Out:
# StatementMeta(, 2037490c-02a6-482f-ab63-915ce14c586e, 5, Finished, Available, Finished, False)

# %%
df = spark.read.table("mtomactual")
df = df.where(df.Country == ParameterCountry)
display(df)

df.write.mode("overwrite").format("delta").saveAsTable("MtoMActualExtract")
# Out:
# StatementMeta(, 2037490c-02a6-482f-ab63-915ce14c586e, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 331f8c9e-8d43-4ab2-b87f-8da80752e834)
