# %% [markdown]
# ## Query Products Data

# %%
df = spark.sql("SELECT * FROM MonitorHubLakehouse.dbo.products LIMIT 1000")
display(df)
# Out:
# StatementMeta(, b3db08be-f01f-4b03-9d7d-bb0dfe0403b4, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1e3bc055-223e-4863-ab0f-4c693c69098c)
