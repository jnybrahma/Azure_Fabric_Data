# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df = spark.read.format("csv").option("header","true").load("Files/MtoMActual.csv")
# df now is a Spark DataFrame containing CSV data from "Files/MtoMActual.csv".
display(df)
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, bf3f9c79-4481-4faf-b9de-8e66afa443a7)

# %%
df.write.mode("overwrite").format("csv").save("Files/MtoMActual2.csv")
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 13, Finished, Available, Finished, False)

# %%
df2 = spark.read.format("csv").option("header","true").load("Files/MtoMActual2.csv")

display(df2)
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 14, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d164a0f1-d057-4a90-a1b1-c28da28ff60a)

# %%
df.write.mode("overwrite").format("delta").saveAsTable("MtoMActual")
# Out:
# StatementMeta(, ee7885b9-3a20-48c2-b825-3c514268a00b, 15, Finished, Available, Finished, False)
