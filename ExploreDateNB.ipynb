# %% [markdown]
# ## Perform Data Exploration

# %%
# Azure Open Dataset connection details
blob_account_name = "azureopendatastorage"
blob_container_name = "mlsamples"
blob_relative_path = "diabetes"
blob_sas_token = r""  # Blank  since container is Anonymous access

# Set Spark config to access blob storage
wasbs_path = f"wasbs://%s@%s.blob.core.windows.net/%s" % (blob_container_name, blob_account_name, blob_relative_path)
# spark.conf.set("fs.azure.sas.%s.%s.blob.core.windows.net" % (blob_container_name, blob_account_name), blob_sas_token)
spark.conf.set(f"fs.azure.sas.{blob_container_name}.{blob_account_name}.blob.core.windows.net", blob_sas_token)
print("Remote blob path :" + wasbs_path)

# Spark read parquet , note that it won't load any data yet by now
df = spark.read.parquet(wasbs_path)
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 3, Finished, Available, Finished, False)
# Remote blob path :wasbs://mlsamples@azureopendatastorage.blob.core.windows.net/diabetes

# %%
display(df)
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, cabe068c-3aa6-4ac1-a696-c968addb1033)

# %%
df = df.toPandas()
df.head()
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 5, Finished, Available, Finished, False)
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
print("Rows:", df.shape[0])
print("\nColumns:", df.shape[1])

print("\nData Types of Columns:")
print(df.dtypes)
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 6, Finished, Available, Finished, False)
# Rows: 442
#
# Columns: 11
#
# Data Types of Columns:
# AGE      int64
# SEX      int64
# BMI    float64
# BP     float64
# S1       int64
# S2     float64
# S3     float64
# S4     float64
# S5     float64
# S6       int64
# Y        int64
# dtype: object

# %%
missing_values = df.isnull().sum()

print("\nMissing values per column:")
print(missing_values)
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 8, Finished, Available, Finished, False)
# Missing values per column:
# AGE    0
# SEX    0
# BMI    0
# BP     0
# S1     0
# S2     0
# S3     0
# S4     0
# S5     0
# S6     0
# Y      0
# dtype: int64

# %% [markdown]
# ## Generate descriptive statistics for numerical variables

# %%
df.describe()
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 9, Finished, Available, Finished, False)
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# min     22.000000    2.000000    3.258100   58.000000   25.000000
# 25%     40.250000    3.000000    4.276700   83.250000   87.000000
# 50%     48.000000    4.000000    4.620050   91.000000  140.500000
# 75%     57.750000    5.000000    4.997200   98.000000  211.500000
# max     99.000000    9.090000    6.107000  124.000000  346.000000

# %% [markdown]
# ## Plot Data Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

mean = df['BMI'].mean()
median = df['BMI'].median()


plt.figure(figsize=(8,6))
plt.hist(df['BMI'], bins=20, color='skyblue', edgecolor='black')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')

plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(median, color='green', linestyle='dashed', linewidth=2, label='Median')

plt.legend()
plt.show()
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 11, Finished, Available, Finished, False)

# %% [markdown]
# ## Perform MultiVariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns



plt.figure(figsize=(8,6))
sns.scatterplot(x='BMI', y='Y', data=df)
plt.title('BMI vs. Target variable')
plt.xlabel('BMI')
plt.ylabel('Target')
plt.show()
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 14, Finished, Available, Finished, False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig , ax = plt.subplots(figsize=(7,5))

df['SEX'] = df['SEX'].replace({1: 'Male', 2: 'Female'})

sns.boxplot(x='SEX', y='BP', data=df, ax=ax)
ax.set_title('Blood pressure across Gender')
plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 193, Finished, Available, Finished, False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

avg_values = df.groupby('SEX')[['BP', 'BMI']].mean()

ax = avg_values.plot(kind='bar', figsize=(15, 6), edgecolor='black')

plt.title('Avg. Blood Pressure and BMI by Gender')
plt.xlabel('Gender')
plt.ylabel('Average')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
            (p.get_x() + p.get_width() / 2. , p.get_height()),
            ha = 'center', va = 'center',
            xytext = (0, 10),
            textcoords ='offset points')

plt.show()
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 196, Finished, Available, Finished, False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.lineplot(x='AGE', y='BMI', data=df, errorbar=None)
plt.title('BMI over Age')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.grid()
plt.show()
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 262, Finished, Available, Finished, False)
# /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Correlation Analysis

# %%
df.corr(numeric_only=True)
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 265, Finished, Available, Finished, False)
#           AGE       BMI        BP        S1        S2        S3        S4  \
# AGE  1.000000  0.185085  0.335428  0.260061  0.219243 -0.075181  0.203841
# BMI  0.185085  1.000000  0.395411  0.249777  0.261170 -0.366811  0.413807
# BP   0.335428  0.395411  1.000000  0.242464  0.185548 -0.178762  0.257650
# S1   0.260061  0.249777  0.242464  1.000000  0.896663  0.051519  0.542207
# S2   0.219243  0.261170  0.185548  0.896663  1.000000 -0.196455  0.659817
# S3  -0.075181 -0.366811 -0.178762  0.051519 -0.196455  1.000000 -0.738493
# S4   0.203841  0.413807  0.257650  0.542207  0.659817 -0.738493  1.000000
# S5   0.270774  0.446157  0.393480  0.515503  0.318357 -0.398577  0.617859
# S6   0.301731  0.388680  0.390430  0.325717  0.290600 -0.273697  0.417212
# Y    0.187889  0.586450  0.441482  0.212022  0.174054 -0.394789  0.430453
#
#            S5        S6         Y
# AGE  0.270774  0.301731  0.187889
# BMI  0.446157  0.388680  0.586450
# BP   0.393480  0.390430  0.441482
# S1   0.515503  0.325717  0.212022
# S2   0.318357  0.290600  0.174054
# S3  -0.398577 -0.273697 -0.394789
# S4   0.617859  0.417212  0.430453
# S5   1.000000  0.464669  0.565883
# S6   0.464669  1.000000  0.382483
# Y    0.565883  0.382483  1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(numeric_only=True))
# Out:
# StatementMeta(, ba631890-d0cb-4a18-8a94-44c47d19a6df, 266, Finished, Available, Finished, False)
# <Axes: >
